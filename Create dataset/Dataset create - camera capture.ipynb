# %%
import cv2
import time
import os

# Inisialisasi kamera (biasanya 0 adalah kamera default, Anda mungkin perlu mengubahnya jika ada beberapa kamera)
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Tidak dapat membuka kamera.")
    exit()

# Buat folder 'datasets' jika belum ada
if not os.path.exists('datasets'):
    os.makedirs('datasets')

# Inisialisasi variabel waktu
start_time = time.time()
save_interval = 0.25  # Interval penyimpanan gambar dalam detik (250 ms)
frame_count = 0

while True:
    # Baca frame dari kamera
    ret, frame = cap.read()
    frame = cv2.resize(frame, (1280, 720))
    
    if not ret:
        print("Error: Tidak dapat membaca frame dari kamera.")
        break
    
    # Tampilkan frame 
    cv2.imshow('Camera Capture', frame)

    # Simpan gambar setiap 250 ms
    if time.time() - start_time >= save_interval:
        # Buat nama file berdasarkan frame count
        file_name = os.path.join('datasets', f'image_{frame_count:04d}.png')
        # Simpan frame sebagai gambar
        cv2.imwrite(file_name, frame)
        print(f"Saved {file_name}")
        frame_count += 1
        # Reset start_time
        start_time = time.time()

    # Tekan 'q' untuk keluar dari loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Bersihkan setelah selesai
cap.release()
cv2.destroyAllWindows()
# Out:
# Saved datasets\image_0000.png
# Saved datasets\image_0001.png
# Saved datasets\image_0002.png
# Saved datasets\image_0003.png
# Saved datasets\image_0004.png
# Saved datasets\image_0005.png
# Saved datasets\image_0006.png
# Saved datasets\image_0007.png
# Saved datasets\image_0008.png
# Saved datasets\image_0009.png
# Saved datasets\image_0010.png
# Saved datasets\image_0011.png
# Saved datasets\image_0012.png
# Saved datasets\image_0013.png
# Saved datasets\image_0014.png
# Saved datasets\image_0015.png
# Saved datasets\image_0016.png
# Saved datasets\image_0017.png
# Saved datasets\image_0018.png
# Saved datasets\image_0019.png
# Saved datasets\image_0020.png
# Saved datasets\image_0021.png
# Saved datasets\image_0022.png
# Saved datasets\image_0023.png
# Saved datasets\image_0024.png
# Saved datasets\image_0025.png
# Saved datasets\image_0026.png
# Saved datasets\image_0027.png
# Saved datasets\image_0028.png
# Saved datasets\image_0029.png
# Saved datasets\image_0030.png
# ...
